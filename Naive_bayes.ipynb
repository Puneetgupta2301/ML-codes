# %% [markdown]
# <a href="https://colab.research.google.com/github/Puneetgupta2301/ML-codes/blob/main/Naive_bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as plt

# %%
data=pd.read_csv('play.csv')

# %%
data.head()
# Out:
#    outlook temperature humidity    wind play
# 0    sunny         hot     high    weak   no
# 1    sunny         hot     high  strong   no
# 2  outlook         hot     high    weak  yes
# 3     rain        mild     high    weak  yes
# 4     rain        cool   normal    weak  yes

# %%
figure = plt.parallel_categories(data[['temperature', 'play', ]], height=500, width=500)

# %%
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data['outlook']= le.fit_transform(data['outlook'])
data['temperature']= le.fit_transform(data['temperature'])
data['humidity']= le.fit_transform(data['humidity'])
data['wind']= le.fit_transform(data['wind'])

# %%
data.head()
# Out:
#    outlook  temperature  humidity  wind play
# 0        3            1         0     1   no
# 1        3            1         0     0   no
# 2        0            1         0     1  yes
# 3        2            2         0     1  yes
# 4        2            0         1     1  yes

# %%
X=data.drop('play', axis=1)
y=data['play']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,  X_test, y_train, y_test=train_test_split(X,y,test_size=0.2, random_state=101)

# %%
y_train
# Out:
# 13     no
# 10    yes
# 5      no
# 0      no
# 4     yes
# 8     yes
# 9     yes
# 7      no
# 6     yes
# 1      no
# 11    yes
# Name: play, dtype: object

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model=GaussianNB()

# %%
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
X_test
# Out:
#     outlook  temperature  humidity  wind
# 12        1            1         1     1
# 2         0            1         0     1
# 3         2            2         0     1

# %%
y_pred =model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6666666666666666

# %% [markdown]
# # New Section
